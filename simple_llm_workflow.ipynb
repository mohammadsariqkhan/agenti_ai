# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import GoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("GOOGLE_API_KEY")
model = GoogleGenerativeAI(model="gemini-2.5-flash",google_api_key=api_key)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
class LLMState(TypedDict):
    question: str
    answer: str

# %%
def llm_qa(state: LLMState) -> LLMState:
    # extract questions from state
    question = state['question']
    # form a prompt
    prompt = f'Answer the following question {question}'
    # ask that question to the llm
    answer = model.invoke(prompt)
    #update the answer in the state
    state['answer'] = answer
    return state

# %%
#create graph
graph = StateGraph(LLMState)

#add nodes
graph.add_node('llm_qa',llm_qa)

# add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)                 

# compile
workflow = graph.compile()

# %%
#execute
initial_state = {
    'question': "How far is moon from earth?"
}
final_state = workflow.invoke(initial_state)
print(final_state['answer'])
# Out:
# The average distance from the Earth to the Moon is approximately **384,400 kilometers (238,900 miles)**.
#
# However, this distance is not constant because the Moon's orbit around the Earth is elliptical, not a perfect circle. This means there's a closest point (perigee) and a farthest point (apogee):
#
# *   **At its closest (perigee):** The Moon can be about 363,104 kilometers (225,623 miles) away.
# *   **At its farthest (apogee):** It can be about 405,696 kilometers (252,088 miles) away.
#
# To put it in perspective, light from the Moon takes about 1.28 seconds to reach Earth.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash",google_api_key='AIzaSyBGlCwOvkwjzjAT5tSHI91GBuvGvId4bUQ')

response = model.invoke("how far is moon from earth?")
answer = response.content
print(answer)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# The Moon's distance from Earth isn't constant because its orbit is elliptical, not a perfect circle.
#
# Here are the key figures:
#
# *   **Average Distance:** Approximately **384,400 kilometers (238,900 miles)**
# *   **Closest Point (Perigee):** Around **363,104 kilometers (225,623 miles)**
# *   **Farthest Point (Apogee):** Around **405,696 kilometers (252,088 miles)**
#
# Light from the Moon takes about **1.28 seconds** to reach Earth.
